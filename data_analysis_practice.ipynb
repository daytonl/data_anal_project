# %%
import pandas as pd
data = {
    'name':['채치수','정대만','송태섭','서태웅','강백호','변덕규','황태산','윤대협'],
    'school':['북산고','북산고','북산고','북산고','북산고','능남고','능남고','능남고'],
    'height':[197,184,168,187,188,202,188,190],
    'english':[90,40,80,40,15,80,55,100],
    'math':[100,50,60,40,70,70,95,77]
}
df = pd.DataFrame(data, index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df.index.name = '지원번호'
df
# Out:
#      name school  height  english  math
# 지원번호
# 1번    채치수    북산고     197       90   100
# 2번    정대만    북산고     184       40    50
# 3번    송태섭    북산고     168       80    60
# 4번    서태웅    북산고     187       40    40
# 5번    강백호    북산고     188       15    70
# 6번    변덕규    능남고     202       80    70
# 7번    황태산    능남고     188       55    95
# 8번    윤대협    능남고     190      100    77

# %% [markdown]
# # Column 수정

# %%
df['school'].replace({'북산고' : '상북고'}, inplace=True)
df
# Out:
#      name school  height  english  math
# 지원번호
# 1번    채치수    상북고     197       90   100
# 2번    정대만    상북고     184       40    50
# 3번    송태섭    상북고     168       80    60
# 4번    서태웅    상북고     187       40    40
# 5번    강백호    상북고     188       15    70
# 6번    변덕규    능남고     202       80    70
# 7번    황태산    능남고     188       55    95
# 8번    윤대협    능남고     190      100    77

# %%
df['school'] =df['school']+'등학교'
df
# Out:
#      name  school  height  english  math
# 지원번호
# 1번    채치수  상북고등학교     197       90   100
# 2번    정대만  상북고등학교     184       40    50
# 3번    송태섭  상북고등학교     168       80    60
# 4번    서태웅  상북고등학교     187       40    40
# 5번    강백호  상북고등학교     188       15    70
# 6번    변덕규  능남고등학교     202       80    70
# 7번    황태산  능남고등학교     188       55    95
# 8번    윤대협  능남고등학교     190      100    77

# %%
df.drop(columns=['math'])
# Out:
#      name  school  height  english
# 지원번호
# 1번    채치수  상북고등학교     197       90
# 2번    정대만  상북고등학교     184       40
# 3번    송태섭  상북고등학교     168       80
# 4번    서태웅  상북고등학교     187       40
# 5번    강백호  상북고등학교     188       15
# 6번    변덕규  능남고등학교     202       80
# 7번    황태산  능남고등학교     188       55
# 8번    윤대협  능남고등학교     190      100

# %%
df.drop(columns=['school'])
# Out:
#      name  height  english  math
# 지원번호
# 1번    채치수     197       90   100
# 2번    정대만     184       40    50
# 3번    송태섭     168       80    60
# 4번    서태웅     187       40    40
# 5번    강백호     188       15    70
# 6번    변덕규     202       80    70
# 7번    황태산     188       55    95
# 8번    윤대협     190      100    77

# %%
filt = df['math']<80
df[filt]
# Out:
#      name  school  height  english  math
# 지원번호
# 2번    정대만  상북고등학교     184       40    50
# 3번    송태섭  상북고등학교     168       80    60
# 4번    서태웅  상북고등학교     187       40    40
# 5번    강백호  상북고등학교     188       15    70
# 6번    변덕규  능남고등학교     202       80    70
# 8번    윤대협  능남고등학교     190      100    77

# %%
def add_cm(height):
  return str(height) +'cm'

  df['height'] =df['height'].apply(add_cm)
  df

# %%
df['school']=df['school']+'등학교'
df
# Out:
#      name     school  height  english  math
# 지원번호
# 1번    채치수  상북고등학교등학교     197       90   100
# 2번    정대만  상북고등학교등학교     184       40    50
# 3번    송태섭  상북고등학교등학교     168       80    60
# 4번    서태웅  상북고등학교등학교     187       40    40
# 5번    강백호  상북고등학교등학교     188       15    70
# 6번    변덕규  능남고등학교등학교     202       80    70
# 7번    황태산  능남고등학교등학교     188       55    95
# 8번    윤대협  능남고등학교등학교     190      100    77

# %%
def capitalize(lang):
  if pd.notnull(lang):
    return lang.capitalize()
    return lang

    df

# %%
def add_cm(height):
  return str(height) +'cm'

  df['height'] =df['height'].apply(add_cm)
  df

# %%
df.groupby('school')
df
# Out:
#      name     school  height  english  math
# 지원번호
# 1번    채치수  상북고등학교등학교     197       90   100
# 2번    정대만  상북고등학교등학교     184       40    50
# 3번    송태섭  상북고등학교등학교     168       80    60
# 4번    서태웅  상북고등학교등학교     187       40    40
# 5번    강백호  상북고등학교등학교     188       15    70
# 6번    변덕규  능남고등학교등학교     202       80    70
# 7번    황태산  능남고등학교등학교     188       55    95
# 8번    윤대협  능남고등학교등학교     190      100    77

# %%
df['school']=df['school']
df
# Out:
#      name     school  height  english  math
# 지원번호
# 1번    채치수  상북고등학교등학교     197       90   100
# 2번    정대만  상북고등학교등학교     184       40    50
# 3번    송태섭  상북고등학교등학교     168       80    60
# 4번    서태웅  상북고등학교등학교     187       40    40
# 5번    강백호  상북고등학교등학교     188       15    70
# 6번    변덕규  능남고등학교등학교     202       80    70
# 7번    황태산  능남고등학교등학교     188       55    95
# 8번    윤대협  능남고등학교등학교     190      100    77

# %%
df['school']= df['school'] -'등학교'
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     217     try:
# --> 218         result = func(left, right)
#     219     except TypeError:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-de3d6c24097a> in <cell line: 1>()
# ----> 1 df['school']= df['school'] -'등학교'
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# ...

# %%
df['학년']=[3,3,2,1,1,3,2,2]
df
# Out:
#      name     school  height  english  math  학년
# 지원번호
# 1번    채치수  상북고등학교등학교     197       90   100   3
# 2번    정대만  상북고등학교등학교     184       40    50   3
# 3번    송태섭  상북고등학교등학교     168       80    60   2
# 4번    서태웅  상북고등학교등학교     187       40    40   1
# 5번    강백호  상북고등학교등학교     188       15    70   1
# 6번    변덕규  능남고등학교등학교     202       80    70   3
# 7번    황태산  능남고등학교등학교     188       55    95   2
# 8번    윤대협  능남고등학교등학교     190      100    77   2

# %%
df.groupby('school').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-c564a220e193> in <cell line: 1>()
# ----> 1 school|['학년'],value_counts().loc['북산고']
#
# NameError: name 'school' is not defined

# %%
import pandas as pd
data = {
    '영화' : ['명량', '극한직업', '신과함께-죄와 벌', '국제시장', '괴물', '도둑들', '7번방의 선물', '암살'],
    '개봉 연도' : [2014, 2019, 2017, 2014, 2006, 2012, 2013, 2015],
    '관객 수' : [1761, 1626, 1441, 1426, 1301, 1298, 1281, 1270], # (단위 : 만 명)
    '평점' : [8.88, 9.20, 8.73, 9.16, 8.62, 7.64, 8.83, 9.10]
}
df = pd.DataFrame(data)
df
# Out:
#           영화  개봉 연도  관객 수    평점
# 0         명량   2014  1761  8.88
# 1       극한직업   2019  1626  9.20
# 2  신과함께-죄와 벌   2017  1441  8.73
# 3       국제시장   2014  1426  9.16
# 4         괴물   2006  1301  8.62
# 5        도둑들   2012  1298  7.64
# 6    7번방의 선물   2013  1281  8.83
# 7         암살   2015  1270  9.10

# %%
df['영화']
# Out:
# 0           명량
# 1         극한직업
# 2    신과함께-죄와 벌
# 3         국제시장
# 4           괴물
# 5          도둑들
# 6      7번방의 선물
# 7           암살
# Name: 영화, dtype: object

# %%
df[['영화','평점']]
# Out:
#           영화    평점
# 0         명량  8.88
# 1       극한직업  9.20
# 2  신과함께-죄와 벌  8.73
# 3       국제시장  9.16
# 4         괴물  8.62
# 5        도둑들  7.64
# 6    7번방의 선물  8.83
# 7         암살  9.10

# %%
df.loc[df['개봉 연도'] >= 2015, ['영화','개봉 연도']]
# Out:
#           영화  개봉 연도
# 1       극한직업   2019
# 2  신과함께-죄와 벌   2017
# 7         암살   2015

# %%
df['추천 점수'] = (df['관객 수']*df['평점']) //100
df
# Out:
#           영화  개봉 연도  관객 수    평점  추천 점수
# 0         명량   2014  1761  8.88  156.0
# 1       극한직업   2019  1626  9.20  149.0
# 2  신과함께-죄와 벌   2017  1441  8.73  125.0
# 3       국제시장   2014  1426  9.16  130.0
# 4         괴물   2006  1301  8.62  112.0
# 5        도둑들   2012  1298  7.64   99.0
# 6    7번방의 선물   2013  1281  8.83  113.0
# 7         암살   2015  1270  9.10  115.0

# %%
df.sort_values('개봉 연도', ascending=False)
# Out:
#           영화  개봉 연도  관객 수    평점  추천 점수
# 1       극한직업   2019  1626  9.20  149.0
# 2  신과함께-죄와 벌   2017  1441  8.73  125.0
# 7         암살   2015  1270  9.10  115.0
# 0         명량   2014  1761  8.88  156.0
# 3       국제시장   2014  1426  9.16  130.0
# 6    7번방의 선물   2013  1281  8.83  113.0
# 5        도둑들   2012  1298  7.64   99.0
# 4         괴물   2006  1301  8.62  112.0
